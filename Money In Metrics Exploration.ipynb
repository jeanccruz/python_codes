# %%
# !pip install vertica_python
# Out:
# Requirement already satisfied: vertica_python in c:\users\jcruz10\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: python-dateutil>=1.5 in c:\users\jcruz10\anaconda3\lib\site-packages (from vertica_python) (2.8.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\jcruz10\anaconda3\lib\site-packages (from vertica_python) (1.15.0)

# %%
import vertica_python
import pandas as pd

# %%
conn_info = {'host': 'prodint.vertica-sbg.a.intuit.com',
             'port': 5433,
             'user': 'jcruz10',
             'password': 'Energy021089',
             'database': 'IDEA',
             # autogenerated session label by default,å
             'session_label': 'some_label',
            # default throw error on invalid UTF-8 results
              'unicode_error': 'strict',
             # SSL is disabled by default
               'ssl': True,
                 # using server-side prepared statements is disabled by default
                 'use_prepared_statements': False,
                 # connection timeout is not enabled by default
                 'connection_timeout': 8000}

# simple connection, with manual close
connection = vertica_python.connect(**conn_info)

# %%
# simple connection, with manual close
connection = vertica_python.connect(**conn_info)

# %%
sql_query="select * from SBG_PUBLISHEDqbobr_moneyinmetrics"
data=pd.read_sql(sql_query,connection)

# %%
data.head(10)
# Out:
#    year  month  invoicing_companies  invoicing_companies_got_paid  \
# 0  2020      3                 1047                           794
# 1  2020      6                 1293                           930
# 2  2020      7                 1508                          1120
# 3  2020     10                 1782                          1327
# 4  2020      9                 1719                          1284
# 5  2020      1                 1040                           754
# 6  2020      5                 1065                           783
# 7  2020      8                 1645                          1209
# 8  2020      4                  986                           731
# 9  2020      2                 1056                           763
#
#    avg_invoices_per_company  invoices_with_boleto  boleto_issuers  \
# 0                 40.255014                   364              42
# 1                 35.258314                   829              78
# 2                 62.944297                  1621             128
# 3                 45.512907                  3491             169
# 4                 44.595695                  2835             175
# 5                 60.065385                   341              41
# 6                 39.217840                   473              51
# 7                 44.276596                  2439             145
# 8                 36.167343                   389              43
# 9                 39.114583                   312              42
#
#    boleto_issuers_got_paid  nf_issuers  nf_issuers_got_paid  ...  \
# 0                       39          30                   18  ...
# 1                       72          53                   40  ...
# 2                      125          74                   59  ...
# 3                      164          90                   67  ...
# 4                      163          92                   67  ...
# 5                       40          27                   22  ...
# 6                       48          39                   32  ...
# 7                      139          93                   73  ...
# 8                       40          31                   22  ...
# 9                       41          30                   17  ...
#
#    percent_invoices_with_nota_fiscal_for_issuers  \
# 0                                       0.256538
# 1                                       0.268429
# 2                                       0.308030
# 3                                       0.439947
# 4                                       0.446626
# 5                                       0.195411
# 6                                       0.194549
# 7                                       0.369748
# 8                                       0.304954
# 9                                       0.290162
#
#    percent_invoices_with_boleto_and_nota_fiscal_for_issuers  \
# 0                                           0.090741
# 1                                           0.108559
# 2                                           0.133556
# 3                                           0.178947
# 4                                           0.196787
# 5                                           0.039773
# 6                                           0.099237
# 7                                           0.152866
# 8                                           0.113003
# 9                                           0.104839
#
#    avg_invoices_per_boleto_issuer  avg_invoices_per_nf_issuer  \
# 0                       54.095238                   26.766667
# 1                       49.243590                   47.094340
# 2                       45.445312                   30.797297
# 3                       50.710059                   25.255556
# 4                       47.291429                   21.586957
# 5                       70.756098                   50.037037
# 6                       56.098039                   27.282051
# 7                       52.537931                   31.989247
# 8                       62.441860                   41.677419
# 9                       73.428571                   26.766667
#
#    avg_boletos_per_issuer  avg_notas_fiscais_per_issuer  num_invoices  \
# 0                8.666667                      6.866667         42147
# 1               10.628205                     12.641509         45589
# 2               12.664062                      9.486486         94920
# 3               20.656805                     11.111111         81104
# 4               16.200000                      9.641304         76660
# 5                8.317073                      9.777778         62468
# 6                9.274510                      5.307692         41767
# 7               16.820690                     11.827957         72835
# 8                9.046512                     12.709677         35661
# 9                7.428571                      7.766667         41305
#
#    num_invoices_paid  percent_invoices_paid  \
# 0              32449               0.769901
# 1              34060               0.747110
# 2              68910               0.725980
# 3              46182               0.569417
# 4              52804               0.688808
# 5              52951               0.847650
# 6              29996               0.718175
# 7              50975               0.699870
# 8              27604               0.774067
# 9              31068               0.752161
#
#    avg_percent_paid_got_paid_companies
# 0                             0.800728
# 1                             0.828443
# 2                             0.814327
# 3                             0.713318
# 4                             0.774463
# 5                             0.827493
# 6                             0.826508
# 7                             0.790354
# 8                             0.816294
# 9                             0.821204
#
# [10 rows x 23 columns]

# %%
data.describe()
# Out:
#          year     month  invoicing_companies  invoicing_companies_got_paid  \
# count    10.0  10.00000            10.000000                     10.000000
# mean   2020.0   5.50000          1314.100000                    969.500000
# std       0.0   3.02765           318.538485                    240.331831
# min    2020.0   1.00000           986.000000                    731.000000
# 25%    2020.0   3.25000          1049.250000                    768.000000
# 50%    2020.0   5.50000          1179.000000                    862.000000
# 75%    2020.0   7.75000          1610.750000                   1186.750000
# max    2020.0  10.00000          1782.000000                   1327.000000
#
#        avg_invoices_per_company  invoices_with_boleto  boleto_issuers  \
# count                 10.000000             10.000000       10.000000
# mean                  44.740797           1309.400000       91.400000
# std                    9.502890           1204.795806       56.566971
# min                   35.258314            312.000000       41.000000
# 25%                   39.140398            370.250000       42.250000
# 50%                   42.265805            651.000000       64.500000
# 75%                   45.283604           2234.500000      140.750000
# max                   62.944297           3491.000000      175.000000
#
#        boleto_issuers_got_paid  nf_issuers  nf_issuers_got_paid  ...  \
# count                10.000000   10.000000             10.00000  ...
# mean                 87.100000   55.900000             41.70000  ...
# std                  54.198093   28.403638             22.61784  ...
# min                  39.000000   27.000000             17.00000  ...
# 25%                  40.250000   30.250000             22.00000  ...
# 50%                  60.000000   46.000000             36.00000  ...
# 75%                 135.500000   86.000000             65.00000  ...
# max                 164.000000   93.000000             73.00000  ...
#
#        percent_invoices_with_nota_fiscal_for_issuers  \
# count                                      10.000000
# mean                                        0.307439
# std                                         0.088523
# min                                         0.194549
# 25%                                         0.259511
# 50%                                         0.297558
# 75%                                         0.354318
# max                                         0.446626
#
#        percent_invoices_with_boleto_and_nota_fiscal_for_issuers  \
# count                                          10.000000
# mean                                            0.121831
# std                                             0.045625
# min                                             0.039773
# 25%                                             0.100637
# 50%                                             0.110781
# 75%                                             0.148039
# max                                             0.196787
#
#        avg_invoices_per_boleto_issuer  avg_invoices_per_nf_issuer  \
# count                       10.000000                   10.000000
# mean                        56.204813                   32.925324
# std                          9.655582                    9.835673
# min                         45.445312                   21.586957
# 25%                         49.610207                   26.766667
# 50%                         53.316585                   29.039674
# 75%                         60.855905                   39.255376
# max                         73.428571                   50.037037
#
#        avg_boletos_per_issuer  avg_notas_fiscais_per_issuer  num_invoices  \
# count               10.000000                     10.000000     10.000000
# mean                11.970309                      9.713685  59445.600000
# std                  4.470368                      2.479722  20845.554379
# min                  7.428571                      5.307692  35661.000000
# 25%                  8.761628                      8.196622  41862.000000
# 50%                  9.951357                      9.709541  54028.500000
# 75%                 15.316016                     11.648746  75703.750000
# max                 20.656805                     12.709677  94920.000000
#
#        num_invoices_paid  percent_invoices_paid  \
# count          10.000000              10.000000
# mean        42699.900000               0.729314
# std         13658.756747               0.072036
# min         27604.000000               0.569417
# 25%         31413.250000               0.704446
# 50%         40121.000000               0.736545
# 75%         52346.750000               0.765466
# max         68910.000000               0.847650
#
#        avg_percent_paid_got_paid_companies
# count                            10.000000
# mean                              0.801313
# std                               0.035637
# min                               0.713318
# 25%                               0.792948
# 50%                               0.815311
# 75%                               0.825182
# max                               0.828443
#
# [8 rows x 23 columns]

# %%
df_datainALL = pd.DataFrame(data=data)
df_datainALL.head()
# Out:
#    year  month  invoicing_companies  invoicing_companies_got_paid  \
# 0  2020      3                 1047                           794
# 1  2020      6                 1293                           930
# 2  2020      7                 1508                          1120
# 3  2020     10                 1782                          1327
# 4  2020      9                 1719                          1284
#
#    avg_invoices_per_company  invoices_with_boleto  boleto_issuers  \
# 0                 40.255014                   364              42
# 1                 35.258314                   829              78
# 2                 62.944297                  1621             128
# 3                 45.512907                  3491             169
# 4                 44.595695                  2835             175
#
#    boleto_issuers_got_paid  nf_issuers  nf_issuers_got_paid  ...  \
# 0                       39          30                   18  ...
# 1                       72          53                   40  ...
# 2                      125          74                   59  ...
# 3                      164          90                   67  ...
# 4                      163          92                   67  ...
#
#    percent_invoices_with_nota_fiscal_for_issuers  \
# 0                                       0.256538
# 1                                       0.268429
# 2                                       0.308030
# 3                                       0.439947
# 4                                       0.446626
#
#    percent_invoices_with_boleto_and_nota_fiscal_for_issuers  \
# 0                                           0.090741
# 1                                           0.108559
# 2                                           0.133556
# 3                                           0.178947
# 4                                           0.196787
#
#    avg_invoices_per_boleto_issuer  avg_invoices_per_nf_issuer  \
# 0                       54.095238                   26.766667
# 1                       49.243590                   47.094340
# 2                       45.445312                   30.797297
# 3                       50.710059                   25.255556
# 4                       47.291429                   21.586957
#
#    avg_boletos_per_issuer  avg_notas_fiscais_per_issuer  num_invoices  \
# 0                8.666667                      6.866667         42147
# 1               10.628205                     12.641509         45589
# 2               12.664062                      9.486486         94920
# 3               20.656805                     11.111111         81104
# 4               16.200000                      9.641304         76660
#
#    num_invoices_paid  percent_invoices_paid  \
# 0              32449               0.769901
# 1              34060               0.747110
# 2              68910               0.725980
# 3              46182               0.569417
# 4              52804               0.688808
#
#    avg_percent_paid_got_paid_companies
# 0                             0.800728
# 1                             0.828443
# 2                             0.814327
# 3                             0.713318
# 4                             0.774463
#
# [5 rows x 23 columns]

# %%
print(df_datainALL.columns)
# Out:
# Index(['year', 'month', 'invoicing_companies', 'invoicing_companies_got_paid',
#        'avg_invoices_per_company', 'invoices_with_boleto', 'boleto_issuers',
#        'boleto_issuers_got_paid', 'nf_issuers', 'nf_issuers_got_paid',
#        'boleto_and_nf_issuers', 'boleto_and_nf_issuers_got_paid',
#        'percent_invoices_with_boleto_for_issuers',
#        'percent_invoices_with_nota_fiscal_for_issuers',
#        'percent_invoices_with_boleto_and_nota_fiscal_for_issuers',
#        'avg_invoices_per_boleto_issuer', 'avg_invoices_per_nf_issuer',
#        'avg_boletos_per_issuer', 'avg_notas_fiscais_per_issuer',
#        'num_invoices', 'num_invoices_paid', 'percent_invoices_paid',
#        'avg_percent_paid_got_paid_companies'],
#       dtype='object')

# %%
df_datain_variables = df_datainALL.drop(df_datainALL.columns[[0,1]], axis=1)

# %%
df_datain_variables.head()
# Out:
#    invoicing_companies  invoicing_companies_got_paid  \
# 0                 1047                           794
# 1                 1293                           930
# 2                 1508                          1120
# 3                 1782                          1327
# 4                 1719                          1284
#
#    avg_invoices_per_company  invoices_with_boleto  boleto_issuers  \
# 0                 40.255014                   364              42
# 1                 35.258314                   829              78
# 2                 62.944297                  1621             128
# 3                 45.512907                  3491             169
# 4                 44.595695                  2835             175
#
#    boleto_issuers_got_paid  nf_issuers  nf_issuers_got_paid  \
# 0                       39          30                   18
# 1                       72          53                   40
# 2                      125          74                   59
# 3                      164          90                   67
# 4                      163          92                   67
#
#    boleto_and_nf_issuers  boleto_and_nf_issuers_got_paid  ...  \
# 0                     10                               9  ...
# 1                     14                              13  ...
# 2                     27                              27  ...
# 3                     32                              32  ...
# 4                     34                              33  ...
#
#    percent_invoices_with_nota_fiscal_for_issuers  \
# 0                                       0.256538
# 1                                       0.268429
# 2                                       0.308030
# 3                                       0.439947
# 4                                       0.446626
#
#    percent_invoices_with_boleto_and_nota_fiscal_for_issuers  \
# 0                                           0.090741
# 1                                           0.108559
# 2                                           0.133556
# 3                                           0.178947
# 4                                           0.196787
#
#    avg_invoices_per_boleto_issuer  avg_invoices_per_nf_issuer  \
# 0                       54.095238                   26.766667
# 1                       49.243590                   47.094340
# 2                       45.445312                   30.797297
# 3                       50.710059                   25.255556
# 4                       47.291429                   21.586957
#
#    avg_boletos_per_issuer  avg_notas_fiscais_per_issuer  num_invoices  \
# 0                8.666667                      6.866667         42147
# 1               10.628205                     12.641509         45589
# 2               12.664062                      9.486486         94920
# 3               20.656805                     11.111111         81104
# 4               16.200000                      9.641304         76660
#
#    num_invoices_paid  percent_invoices_paid  \
# 0              32449               0.769901
# 1              34060               0.747110
# 2              68910               0.725980
# 3              46182               0.569417
# 4              52804               0.688808
#
#    avg_percent_paid_got_paid_companies
# 0                             0.800728
# 1                             0.828443
# 2                             0.814327
# 3                             0.713318
# 4                             0.774463
#
# [5 rows x 21 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
sns.pairplot(df_datain_variables , size=2.5)
plt.show()
# Out:
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df_datain_variables , height=2, hue = 'qbo_channel_super_aggr_name')
# Out:
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\jcruz10\Anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
sns.heatmap(df_datain_variables.corr(), annot=True, cmap="viridis", fmt="0.2f");

# %%
df_datain_variables_numbers = df_datain_variables.drop(df_datain_variables.columns[[0]], axis=1)
df_datain_variables_numbers
# Out:
#    invoicing_companies_got_paid  avg_invoices_per_company  \
# 0                           794                 40.255014
# 1                           930                 35.258314
# 2                          1120                 62.944297
# 3                          1327                 45.512907
# 4                          1284                 44.595695
# 5                           754                 60.065385
# 6                           783                 39.217840
# 7                          1209                 44.276596
# 8                           731                 36.167343
# 9                           763                 39.114583
#
#    invoices_with_boleto  boleto_issuers  boleto_issuers_got_paid  nf_issuers  \
# 0                   364              42                       39          30
# 1                   829              78                       72          53
# 2                  1621             128                      125          74
# 3                  3491             169                      164          90
# 4                  2835             175                      163          92
# 5                   341              41                       40          27
# 6                   473              51                       48          39
# 7                  2439             145                      139          93
# 8                   389              43                       40          31
# 9                   312              42                       41          30
#
#    nf_issuers_got_paid  boleto_and_nf_issuers  boleto_and_nf_issuers_got_paid  \
# 0                   18                     10                               9
# 1                   40                     14                              13
# 2                   59                     27                              27
# 3                   67                     32                              32
# 4                   67                     34                              33
# 5                   22                      9                               8
# 6                   32                     12                              12
# 7                   73                     34                              33
# 8                   22                      8                               8
# 9                   17                      8                               8
#
#    percent_invoices_with_boleto_for_issuers  \
# 0                                  0.160211
# 1                                  0.215829
# 2                                  0.278666
# 3                                  0.407351
# 4                                  0.342557
# 5                                  0.117546
# 6                                  0.165327
# 7                                  0.320163
# 8                                  0.144879
# 9                                  0.101167
#
#    percent_invoices_with_nota_fiscal_for_issuers  \
# 0                                       0.256538
# 1                                       0.268429
# 2                                       0.308030
# 3                                       0.439947
# 4                                       0.446626
# 5                                       0.195411
# 6                                       0.194549
# 7                                       0.369748
# 8                                       0.304954
# 9                                       0.290162
#
#    percent_invoices_with_boleto_and_nota_fiscal_for_issuers  \
# 0                                           0.090741
# 1                                           0.108559
# 2                                           0.133556
# 3                                           0.178947
# 4                                           0.196787
# 5                                           0.039773
# 6                                           0.099237
# 7                                           0.152866
# 8                                           0.113003
# 9                                           0.104839
#
#    avg_invoices_per_boleto_issuer  avg_invoices_per_nf_issuer  \
# 0                       54.095238                   26.766667
# 1                       49.243590                   47.094340
# 2                       45.445312                   30.797297
# 3                       50.710059                   25.255556
# 4                       47.291429                   21.586957
# 5                       70.756098                   50.037037
# 6                       56.098039                   27.282051
# 7                       52.537931                   31.989247
# 8                       62.441860                   41.677419
# 9                       73.428571                   26.766667
#
#    avg_boletos_per_issuer  avg_notas_fiscais_per_issuer  num_invoices  \
# 0                8.666667                      6.866667         42147
# 1               10.628205                     12.641509         45589
# 2               12.664062                      9.486486         94920
# 3               20.656805                     11.111111         81104
# 4               16.200000                      9.641304         76660
# 5                8.317073                      9.777778         62468
# 6                9.274510                      5.307692         41767
# 7               16.820690                     11.827957         72835
# 8                9.046512                     12.709677         35661
# 9                7.428571                      7.766667         41305
#
#    num_invoices_paid  percent_invoices_paid  \
# 0              32449               0.769901
# 1              34060               0.747110
# 2              68910               0.725980
# 3              46182               0.569417
# 4              52804               0.688808
# 5              52951               0.847650
# 6              29996               0.718175
# 7              50975               0.699870
# 8              27604               0.774067
# 9              31068               0.752161
#
#    avg_percent_paid_got_paid_companies
# 0                             0.800728
# 1                             0.828443
# 2                             0.814327
# 3                             0.713318
# 4                             0.774463
# 5                             0.827493
# 6                             0.826508
# 7                             0.790354
# 8                             0.816294
# 9                             0.821204

# %%
import matplotlib.pyplot as plt

f, axes = plt.subplots(4, 4, figsize=(15, 15))
for ax, feature in zip(axes.flat, df_datain_variables_numbers.columns):
    sns.distplot(df_datain_variables_numbers[feature] , color="skyblue", ax=ax)
plt.show()
